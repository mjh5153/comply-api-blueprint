# %% [markdown]
# <a href="https://colab.research.google.com/github/mjh5153/comply-api-blueprint/blob/main/DeepLearning_NeuralNetworks_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Recurrent Neural Network
# Chatgpt
## Designed for sequential data
## Remembers previous information

### Example - sentences - speech - detect stock prices - weather forecast --> AI tool self learn

### Key Ideas -

### Flow: Past ingestion --> current class --> output


### RNN - current word + previous memory -> new memory

### Ex: I + Memory(o)

### Produces -> hidden layer h1


### Step 2 - /Second word arrives
#### input / love
##### Current word = love, previous memory = h1
##### love + h1 = I
##### h1 = I love

### Step 3 - Third word arrives
  ## word = Deep Learning
  ### Deep Learning + h1 i.e understands it as complete sentence, create new memory, h2, h3
  ### Goal - Understands sentence trying to build
  #### Next prompt - I love h1, h2 -> Understand, love + h1 -> output -> deep learning // from memory

#. Back Propogation - through time ( BPTT )

## Error moves backward - T4, t3, etc.., weights updated, predictionWrong ? errorUpdateWeights

# Example: Movie reviews

# Step 1 - user review, user writes / "this movie amazing"

# Step 2 / tokenization - convert sentence to words -> convert to numbers --> Neural Network(computes numbers)

# How? tokenization - [ this , movie, is, amazing, etc.. ]

## Next - convert to decimal - [15, 42, 8, 99]  - random number stored by neural network

# Step 3 - Embedding layer - Convert each word id --> vector --> [15: {0,1,2,0}, 42: {0,2,}]
## Neural network needs to understand each word as positive somehow - [[0.1, 0.4, 0.5], [0.5, 0.8, 0.9], []],

#### Model needs to remember all words -- words related will be close in vector,[[0.85, 0.9, 0.97], [0.87, 0.9, 0.97], [0.87, 0.9, 0.95]],  good, excellent, amazing, fantastic ( vectors near to each other )
##### Use: Websites - Negative words = close in vector, Positive words = close in vector


#### Negative Words - bad, worse, terrible, bad = [-0.7, -0.8, -0.9]

# Step 4 - RNN reads one word at a time , creates h1 memory, read Movie, save movie + h1 -> h2, et..

## Final Layer - final memory - Dense layer -> Calculate positive or negative review

## Benefits - faster than neural network -> words related together

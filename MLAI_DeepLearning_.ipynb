# %% [markdown]
# <a href="https://colab.research.google.com/github/mjh5153/comply-api-blueprint/blob/main/MLAI_DeepLearning_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Input ---- Layer  1 -- Formula calculates activation
## 1 - Activation Value --- > Strongly a neuron detects pattern ---> neuron detects loop AND  image contains loop ? activation value = close to 1 ( strongly found loop) | nultimple nerons, finding loops | combine results ---- Form Circle ? and so on
## forumal f(wx + b )
### f: activation, w: weight, x: input  b: bias
##   n0 < ----         1 vertical Line (.1 < --- less) -----------> N0 < --detect a long ---> 0.8
## 8 n1 0 ,_------ --- > horizontel line ( .2 -> less activation) --|^  ^  ^        cirecle    .9
##   ##   n0 < ----         1 tiny wave (.8 < --- less)----------------|^ |         connected line .1
## ##   n0 < ----         1 diagonal Line (.9 < --- less) ----------------^         wheeel          .2
                                                                            ## N5 = detect loop ? Yes
 ##                                                                                       | 0   increasing activation: probability correlation
## Layer 2 - no vertical, horzontal,


# Understanding Activtion - Decision Tree
## a = f(wx +b) - f is activation function
###  1. neuron <== input
 ### 2.     ? Check for importance ---> weights
###  3.     ? Add bias
###  4.    ? pass to activation f(n)
###  5.  ---> activation Values generated and returned
      #### x -> input ---- pixel value
      ####            ----- previous layer
      ####            ------ function

      #### EX: 255 pixel rbg, Input: # closer and away from 1 or 0
      ####      Normalize: x/255, 201/255, etc...., detects Patterns => horizontal, vertical lines, etc... !== 0

      # Weight -> importance of Input - 0111110 - horizontal line, high weight, neurons strong
      ## High weight -> nuerons care strong
      ## low  weight --> Neurons ignore
      ## b --> bias : ex:  0 --> output ? blank image [ 0000 pixels ]
      ##    --> Helps neurons shift decision boundary neuron1  z = wx + b    | x = .8, w=.9, b = .1 } neuron = 0.82 -> activationFn(neuron) => activation ? ( true) => lossfn(1-0.82) => {layer: [1neurons] ### wrong activation | keep training model over time to improve

      #### forward propogation --> Data moves from / input -> hidden layers -> output
      ####  Steps -> Input enters n/w, weighted sum calculator = E(WiNi + b)

      # Process we follow for Building a neural network:
      ## 1. Collect data, train data, test data
      ## 2. Clean data - expert analysis
      ## 3. Split test/train
      ## 4. Design architecture
      ## 5. Initialize Weight ---> confidence neuron --> more:activate
      ## 6. forward propogation --> create activation code --> apply --> generate output -->
      ## 7. calculate losses ( % answers correct )
      ## 8 Update weights to decrease losses                                           neuron2  z = wx + b
      ## 9. Decrease loss
      ## 10. Repeat --> i.e. more train neurons => less error i.e. update weights



      #### Professor will create a drive and upload

      #### Question - Applications to SWE sdlc -- MLOPS - Upcoming lesson
#

                                                   1: .2       2: .25, 3: 30, 4 5, 6, 7,8

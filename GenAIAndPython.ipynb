# %% [markdown]
# <a href="https://colab.research.google.com/github/mjh5153/comply-api-blueprint/blob/copilot%2Fcreate-dev-environment-for-demo/GenAIAndPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if conditional

a = int(input("Enter first"))
b = int(input("Enter second"))

if a<b:
  print(a, "is less than ", b)
# Out:
# Enter first3
# Enter second5
# 3 is less than  5

# %%
a = int(input("Enter first"))
b = int(input("Enter second"))
c = int(input("Endter thrird"))

# can't have else without if
# All if statements with else, will be checked if no elif
# Moment if is true - elif and else skipped
if a<b:
  print(a, "is less than ", b)
if a<c:
  print(a, " is less than ", c)
elif a==b:
  print(a, "is equal ", b)
else:
  print(b, "is less than ", a)

# %%
## loops - For loop and while

fruits = ["apple", "banana", "orange", "mango", "Grapes"]
